# %%
import pandas as pd
df_churn=pd.read_csv("customer_churn.txt",sep=",")
df_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 17    9959-WOFKT    Male              0      No        Yes      71
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 19    4183-MYFRB  Female              0      No         No      21
# 20    8779-QRDMV    Male              1      No         No       1
# 21    1680-VDCWW    Male              0     Yes         No      12
# 22    1066-JKSGK    Male              0      No         No       1
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# 25    6865-JZNKO  Female              0      No         No      30
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 28    5248-YGIJN    Male              0     Yes         No      72
# 29    8773-HHUOZ  Female              0      No        Yes      17
# ...          ...     ...            ...     ...        ...     ...
# 7013  1685-BQULA  Female              0      No         No      40
# 7014  9053-EJUNL    Male              0      No         No      41
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7016  1471-GIQKQ  Female              0      No         No       1
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7019  9710-NJERN  Female              0      No         No      39
# 7020  9837-FWLCH    Male              0     Yes        Yes      12
# 7021  1699-HPSBG    Male              0      No         No      12
# 7022  7203-OYKCT    Male              0      No         No      72
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7024  7398-LXGYX    Male              0     Yes         No      44
# 7025  2823-LKABH  Female              0      No         No      18
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7027  0550-DCXLH    Male              0      No         No      13
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7029  2235-DWLJU  Female              1      No         No       6
# 7030  0871-OPBXW  Female              0      No         No       2
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7032  6894-LFHLY    Male              1      No         No       1
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# 1             Yes                No             DSL                  Yes  ...
# 2             Yes                No             DSL                  Yes  ...
# 3              No  No phone service             DSL                  Yes  ...
# 4             Yes                No     Fiber optic                   No  ...
# 5             Yes               Yes     Fiber optic                   No  ...
# 6             Yes               Yes     Fiber optic                   No  ...
# 7              No  No phone service             DSL                  Yes  ...
# 8             Yes               Yes     Fiber optic                   No  ...
# 9             Yes                No             DSL                  Yes  ...
# 10            Yes                No             DSL                  Yes  ...
# 11            Yes                No              No  No internet service  ...
# 12            Yes               Yes     Fiber optic                   No  ...
# 13            Yes               Yes     Fiber optic                   No  ...
# 14            Yes                No     Fiber optic                  Yes  ...
# 15            Yes               Yes     Fiber optic                  Yes  ...
# 16            Yes                No              No  No internet service  ...
# 17            Yes               Yes     Fiber optic                  Yes  ...
# 18            Yes                No             DSL                   No  ...
# 19            Yes                No     Fiber optic                   No  ...
# 20             No  No phone service             DSL                   No  ...
# 21            Yes                No              No  No internet service  ...
# 22            Yes                No              No  No internet service  ...
# 23            Yes               Yes             DSL                   No  ...
# 24            Yes                No             DSL                  Yes  ...
# 25            Yes                No             DSL                  Yes  ...
# 26            Yes               Yes     Fiber optic                   No  ...
# 27             No  No phone service             DSL                   No  ...
# 28            Yes               Yes             DSL                  Yes  ...
# 29            Yes                No             DSL                   No  ...
# ...           ...               ...             ...                  ...  ...
# 7013          Yes               Yes     Fiber optic                   No  ...
# 7014          Yes               Yes     Fiber optic                   No  ...
# 7015          Yes                No     Fiber optic                   No  ...
# 7016          Yes                No             DSL                   No  ...
# 7017          Yes                No              No  No internet service  ...
# 7018          Yes                No     Fiber optic                   No  ...
# 7019          Yes                No              No  No internet service  ...
# 7020          Yes                No              No  No internet service  ...
# 7021          Yes                No             DSL                   No  ...
# 7022          Yes               Yes     Fiber optic                   No  ...
# 7023          Yes               Yes     Fiber optic                   No  ...
# 7024          Yes               Yes     Fiber optic                  Yes  ...
# 7025          Yes               Yes     Fiber optic                   No  ...
# 7026          Yes                No             DSL                   No  ...
# 7027          Yes                No             DSL                   No  ...
# 7028          Yes                No             DSL                   No  ...
# 7029           No  No phone service             DSL                   No  ...
# 7030          Yes                No              No  No internet service  ...
# 7031          Yes               Yes             DSL                  Yes  ...
# 7032          Yes               Yes     Fiber optic                   No  ...
# 7033          Yes                No     Fiber optic                   No  ...
# 7034          Yes               Yes     Fiber optic                  Yes  ...
# 7035          Yes                No     Fiber optic                   No  ...
# 7036           No  No phone service             DSL                   No  ...
# 7037          Yes                No              No  No internet service  ...
# 7038          Yes               Yes             DSL                  Yes  ...
# 7039          Yes               Yes     Fiber optic                   No  ...
# 7040           No  No phone service             DSL                  Yes  ...
# 7041          Yes               Yes     Fiber optic                   No  ...
# 7042          Yes                No     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 0                      No                   No                   No
# 1                     Yes                   No                   No
# 2                      No                   No                   No
# 3                     Yes                  Yes                   No
# 4                      No                   No                   No
# 5                     Yes                   No                  Yes
# 6                      No                   No                  Yes
# 7                      No                   No                   No
# 8                     Yes                  Yes                  Yes
# 9                      No                   No                   No
# 10                     No                   No                   No
# 11    No internet service  No internet service  No internet service
# 12                    Yes                   No                  Yes
# 13                    Yes                   No                  Yes
# 14                    Yes                  Yes                  Yes
# 15                    Yes                  Yes                  Yes
# 16    No internet service  No internet service  No internet service
# 17                    Yes                   No                  Yes
# 18                    Yes                  Yes                   No
# 19                    Yes                   No                   No
# 20                    Yes                   No                   No
# 21    No internet service  No internet service  No internet service
# 22    No internet service  No internet service  No internet service
# 23                     No                  Yes                   No
# 24                     No                  Yes                   No
# 25                     No                   No                   No
# 26                     No                   No                  Yes
# 27                     No                   No                   No
# 28                    Yes                  Yes                  Yes
# 29                     No                   No                  Yes
# ...                   ...                  ...                  ...
# 7013                  Yes                   No                  Yes
# 7014                   No                   No                  Yes
# 7015                  Yes                   No                  Yes
# 7016                   No                   No                   No
# 7017  No internet service  No internet service  No internet service
# 7018                   No                   No                   No
# 7019  No internet service  No internet service  No internet service
# 7020  No internet service  No internet service  No internet service
# 7021                   No                  Yes                  Yes
# 7022                  Yes                   No                  Yes
# 7023                  Yes                   No                  Yes
# 7024                  Yes                   No                   No
# 7025                  Yes                  Yes                   No
# 7026                   No                   No                   No
# 7027                   No                  Yes                  Yes
# 7028                   No                  Yes                  Yes
# 7029                   No                   No                  Yes
# 7030  No internet service  No internet service  No internet service
# 7031                   No                   No                   No
# 7032                   No                   No                   No
# 7033                   No                   No                   No
# 7034                  Yes                   No                  Yes
# 7035                   No                   No                  Yes
# 7036                  Yes                  Yes                  Yes
# 7037  No internet service  No internet service  No internet service
# 7038                  Yes                  Yes                  Yes
# 7039                  Yes                   No                  Yes
# 7040                   No                   No                   No
# 7041                   No                   No                   No
# 7042                  Yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 0                      No  Month-to-month              Yes
# 1                      No        One year               No
# 2                      No  Month-to-month              Yes
# 3                      No        One year               No
# 4                      No  Month-to-month              Yes
# 5                     Yes  Month-to-month              Yes
# 6                      No  Month-to-month              Yes
# 7                      No  Month-to-month               No
# 8                     Yes  Month-to-month              Yes
# 9                      No        One year               No
# 10                     No  Month-to-month              Yes
# 11    No internet service        Two year               No
# 12                    Yes        One year               No
# 13                    Yes  Month-to-month              Yes
# 14                    Yes  Month-to-month              Yes
# 15                    Yes        Two year               No
# 16    No internet service        One year               No
# 17                    Yes        Two year               No
# 18                     No  Month-to-month               No
# 19                    Yes  Month-to-month              Yes
# 20                    Yes  Month-to-month              Yes
# 21    No internet service        One year               No
# 22    No internet service  Month-to-month               No
# 23                     No        Two year              Yes
# 24                     No  Month-to-month               No
# 25                     No  Month-to-month              Yes
# 26                    Yes  Month-to-month              Yes
# 27                     No  Month-to-month               No
# 28                    Yes        Two year              Yes
# 29                    Yes  Month-to-month              Yes
# ...                   ...             ...              ...
# 7013                   No  Month-to-month              Yes
# 7014                   No  Month-to-month              Yes
# 7015                   No  Month-to-month              Yes
# 7016                   No  Month-to-month               No
# 7017  No internet service        Two year               No
# 7018                   No  Month-to-month              Yes
# 7019  No internet service        Two year               No
# 7020  No internet service  Month-to-month              Yes
# 7021                   No        One year              Yes
# 7022                  Yes        One year              Yes
# 7023                  Yes  Month-to-month              Yes
# 7024                   No  Month-to-month              Yes
# 7025                  Yes  Month-to-month              Yes
# 7026                   No  Month-to-month              Yes
# 7027                  Yes  Month-to-month               No
# 7028                   No        Two year               No
# 7029                  Yes  Month-to-month              Yes
# 7030  No internet service  Month-to-month              Yes
# 7031                   No        One year               No
# 7032                   No  Month-to-month              Yes
# 7033                   No  Month-to-month              Yes
# 7034                   No  Month-to-month              Yes
# 7035                   No  Month-to-month              Yes
# 7036                  Yes        One year               No
# 7037  No internet service        Two year              Yes
# 7038                  Yes        One year              Yes
# 7039                  Yes        One year              Yes
# 7040                   No  Month-to-month              Yes
# 7041                   No  Month-to-month              Yes
# 7042                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 0              Electronic check          29.85         29.85    No
# 1                  Mailed check          56.95        1889.5    No
# 2                  Mailed check          53.85        108.15   Yes
# 3     Bank transfer (automatic)          42.30       1840.75    No
# 4              Electronic check          70.70        151.65   Yes
# 5              Electronic check          99.65         820.5   Yes
# 6       Credit card (automatic)          89.10        1949.4    No
# 7                  Mailed check          29.75         301.9    No
# 8              Electronic check         104.80       3046.05   Yes
# 9     Bank transfer (automatic)          56.15       3487.95    No
# 10                 Mailed check          49.95        587.45    No
# 11      Credit card (automatic)          18.95         326.8    No
# 12      Credit card (automatic)         100.35        5681.1    No
# 13    Bank transfer (automatic)         103.70        5036.3   Yes
# 14             Electronic check         105.50       2686.05    No
# 15      Credit card (automatic)         113.25       7895.15    No
# 16                 Mailed check          20.65       1022.95    No
# 17    Bank transfer (automatic)         106.70       7382.25    No
# 18      Credit card (automatic)          55.20        528.35   Yes
# 19             Electronic check          90.05        1862.9    No
# 20             Electronic check          39.65         39.65   Yes
# 21    Bank transfer (automatic)          19.80        202.25    No
# 22                 Mailed check          20.15         20.15   Yes
# 23      Credit card (automatic)          59.90        3505.1    No
# 24      Credit card (automatic)          59.60        2970.3    No
# 25    Bank transfer (automatic)          55.30        1530.6    No
# 26             Electronic check          99.35       4749.15   Yes
# 27             Electronic check          30.20          30.2   Yes
# 28      Credit card (automatic)          90.25       6369.45    No
# 29                 Mailed check          64.70        1093.1   Yes
# ...                         ...            ...           ...   ...
# 7013  Bank transfer (automatic)          93.40        3756.4    No
# 7014           Electronic check          89.20       3645.75    No
# 7015    Credit card (automatic)          85.20       2874.45    No
# 7016           Electronic check          49.95         49.95    No
# 7017  Bank transfer (automatic)          20.65       1020.75    No
# 7018               Mailed check          70.65         70.65   Yes
# 7019               Mailed check          20.15           826    No
# 7020           Electronic check          19.20           239    No
# 7021           Electronic check          59.80         727.8   Yes
# 7022           Electronic check         104.95        7544.3    No
# 7023           Electronic check         103.50        6479.4    No
# 7024    Credit card (automatic)          84.80       3626.35    No
# 7025  Bank transfer (automatic)          95.05        1679.4    No
# 7026  Bank transfer (automatic)          44.20        403.35   Yes
# 7027               Mailed check          73.35        931.55    No
# 7028  Bank transfer (automatic)          64.10       4326.25    No
# 7029           Electronic check          44.40        263.05    No
# 7030               Mailed check          20.05         39.25    No
# 7031    Credit card (automatic)          60.00        3316.1    No
# 7032           Electronic check          75.75         75.75   Yes
# 7033    Credit card (automatic)          69.50       2625.25    No
# 7034    Credit card (automatic)         102.95       6886.25   Yes
# 7035  Bank transfer (automatic)          78.70        1495.1    No
# 7036           Electronic check          60.65         743.3    No
# 7037  Bank transfer (automatic)          21.15        1419.4    No
# 7038               Mailed check          84.80        1990.5    No
# 7039    Credit card (automatic)         103.20        7362.9    No
# 7040           Electronic check          29.60        346.45    No
# 7041               Mailed check          74.40         306.6   Yes
# 7042  Bank transfer (automatic)         105.65        6844.5    No
#
# [7043 rows x 21 columns]

# %%
#lets chcek the null values in the dataset
df_churn.isnull().sum()
#We can see in the entire dataset there are no null values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Lets chcek the datatypes of columns
df_churn.dtypes
#Seeing below datatypes on thing is clear that Total charges need to converted to float
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#Lets do the conversion of "TotalCharges" column to float type
df_churn["TotalCharges"]=df_churn["TotalCharges"].str.strip()
df_churn["TotalCharges"]=pd.to_numeric(df_churn["TotalCharges"])

# %%
#Lets chcek the datatypes again
df_churn.dtypes
#Hence we observe datatype has been changed to float for "TotalCharges"
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
#lets chcek the null vaues
df_churn.isnull().sum()
#But above conversion genrated null values in TotalCharges column
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#lets chcek the rows where it raised null values
df_churn.loc[df_churn["TotalCharges"].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# 753           Yes                No              No  No internet service  ...
# 936           Yes                No             DSL                  Yes  ...
# 1082          Yes               Yes              No  No internet service  ...
# 1340           No  No phone service             DSL                  Yes  ...
# 3331          Yes                No              No  No internet service  ...
# 3826          Yes               Yes              No  No internet service  ...
# 4380          Yes                No              No  No internet service  ...
# 5218          Yes                No              No  No internet service  ...
# 6670          Yes               Yes             DSL                   No  ...
# 6754          Yes               Yes             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 488                   Yes                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                   No                  Yes
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                   No                  Yes                   No
#
#           StreamingMovies  Contract PaperlessBilling  \
# 488                    No  Two year              Yes
# 753   No internet service  Two year               No
# 936                   Yes  Two year               No
# 1082  No internet service  Two year               No
# 1340                   No  Two year               No
# 3331  No internet service  Two year               No
# 3826  No internet service  Two year               No
# 4380  No internet service  Two year               No
# 5218  No internet service  One year              Yes
# 6670                   No  Two year               No
# 6754                   No  Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 488   Bank transfer (automatic)          52.55           NaN     No
# 753                Mailed check          20.25           NaN     No
# 936                Mailed check          80.85           NaN     No
# 1082               Mailed check          25.75           NaN     No
# 1340    Credit card (automatic)          56.05           NaN     No
# 3331               Mailed check          19.85           NaN     No
# 3826               Mailed check          25.35           NaN     No
# 4380               Mailed check          20.00           NaN     No
# 5218               Mailed check          19.70           NaN     No
# 6670               Mailed check          73.35           NaN     No
# 6754  Bank transfer (automatic)          61.90           NaN     No
#
# [11 rows x 21 columns]

# %%
#imputing the genrated null values with mean in "TotalCharges"
df_churn["TotalCharges"].fillna(df_churn["TotalCharges"].mean(),inplace=True)

# %%
#Lets again chcek null values
df_churn.isnull().sum()
#Hence imputation is successful
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Also lets delete "customerID" column as it will not add any significance to the model building process
df_churn.drop(columns=["customerID"],inplace=True)

# %%
#Lets chcek the value counts of each column of object datatype
for col in df_churn.columns:
    if df_churn[col].dtype=="object":
        print(df_churn[col].value_counts())
        print()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
#
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
#
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64
#
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64
#
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64
#
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64
#
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64
#
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
#Lets do some graphical EDA
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Churn",data=df_churn)
plt.show()
#this shows dataset is imbalanced hence auc roc curve should be the metric

# %%
#Which "Contract" type of cutsomers are churning more
sns.countplot(x="Contract",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#Customers who have churned are mostly having contract of "Month to Month"

# %%
#Lets seen the churn on the basis of gender
sns.countplot(x="gender",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#So boh type of genders equally churned

# %%
#Lets check the count of churn on the basis "InternetService" 
sns.countplot(x="InternetService",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#High amount of people i.e more than 1200 who churned are having InternetService of Fiber optic type
#So may be this type of service is bad and needs to be focussed on

# %%
#lets check the count of customers who churned on basis of "PaymentMethod"
sns.countplot(x="PaymentMethod",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#Here we obseved churn is higher around 1100 i.e more than 50% of churn where customers are using "Electronic check"
#We can say this mode of payment has multiple issues because of which customers are dissatisfied

# %%
#Lets chcek the count of churn on the basis of "Partner" 
sns.countplot(x="Partner",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#churn in unmarried persons are more compared to married eventhough both type of customers almost equally exist in dataset

# %%
#lets chcek the count of customers churn on the basis "StreamingMovies"
sns.countplot(x="StreamingMovies",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#difficult to infer anything from thi plot

# %%
#lets chcek the count of customers churn on the basis "MultipleLines"
sns.countplot(x="MultipleLines",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()

# %%
df_churn.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#Now lets check the count of "SeniorCitizen"
sns.countplot(x="SeniorCitizen",hue="Churn",data=df_churn)
plt.show()
#Most of the senior citizens churned ...we could inspect the reason for their churn

# %%
#lets chcek the count of customers churn on the basis "MultipleLines"
sns.countplot(x="TechSupport",data=df_churn.loc[df_churn["Churn"]=="Yes"])
plt.show()
#Around 1400 people who churned were not having TechSupport
#We should chcek the reason behind this too

# %%
#lets chcek the average montly charges af the customers who chunrned compared to who didn't
sns.barplot(x="Churn",y="MonthlyCharges",data=df_churn)
plt.show()
#customers who churned were charged more than who didnt

# %%
#lets chcek the average total charges af the customers who chunrned compared to who didn't
sns.barplot(x="Churn",y="TotalCharges",data=df_churn)
plt.show()
#customers who didnt chuned has averge total charges more

# %%
#Lets divide the dataset into input and output
df_x=df_churn.drop(columns=["Churn"])
y=df_churn[["Churn"]]

# %%
#Lets convert our dataset to a numeric form such that our M.L model can understand using on hot encoding
df_x=pd.get_dummies(df_x,drop_first=True)

# %%
#Lets chcek the shape
df_x.shape
#Number column increased from 20 to 30 in input as a result of one hot encoding
# Out:
# (7043, 30)

# %%
from sklearn.preprocessing import LabelEncoder
y=LabelEncoder().fit_transform(y)

# %%
#since it is imbalanced dataset so we will focus on auc-roc score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
def max_aucroc_score(clf,df_x,y):
    max_aucroc_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20,stratify=y)
        x_train, y_train = SMOTE().fit_sample(x_train, y_train)
        clf.fit(x_train,y_train)
        y_pred = clf.predict(x_test)
        aucroc_scr=roc_auc_score(y_test,y_pred)
        print("auc roc score corresponding to ",r_state," is ",aucroc_scr)
        if aucroc_scr>max_aucroc_score:
            max_aucroc_score=aucroc_scr
            final_r_state=r_state
    print("max auc roc score corresponding to ",final_r_state," is ",max_aucroc_score)
    return final_r_state

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    scores=cross_val_score(model,x,y,cv=5,scoring="roc_auc")
    print("Mean roc auc score for classifier: ",scores.mean())
    print("standard deviation in roc auc score for classifier: ",scores.std())
    print(scores)

# %%
#let's bring the features to same scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Lets chcek logistic regression
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")
lg_clf=LogisticRegression()
max_aucroc_score(lg_clf,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7583778966131908
# auc roc score corresponding to  43  is  0.7810380014983596
# auc roc score corresponding to  44  is  0.7792515952362499
# auc roc score corresponding to  45  is  0.759152910175928
# auc roc score corresponding to  46  is  0.7603102637629491
# auc roc score corresponding to  47  is  0.7446265726316877
# auc roc score corresponding to  48  is  0.7763530445116122
# auc roc score corresponding to  49  is  0.7537717326719885
# auc roc score corresponding to  50  is  0.7474915394352735
# auc roc score corresponding to  51  is  0.7818918081066418
# auc roc score corresponding to  52  is  0.7694102146787569
# auc roc score corresponding to  53  is  0.7730954041695729
# auc roc score corresponding to  54  is  0.7667364178873131
# auc roc score corresponding to  55  is  0.7867898938231419
# auc roc score corresponding to  56  is  0.7572205430261696
# auc roc score corresponding to  57  is  0.7613888243044253
# auc roc score corresponding to  58  is  0.7705223591412849
# auc roc score corresponding to  59  is  0.7439187269110542
# auc roc score corresponding to  60  is  0.7758363688031208
# auc roc score corresponding to  61  is  0.7727130641452892
# auc roc score corresponding to  62  is  0.7611304864501796
# auc roc score corresponding to  63  is  0.7679725645198792
# auc roc score corresponding to  64  is  0.7810380014983596
# auc roc score corresponding to  65  is  0.7677697693042961
# auc roc score corresponding to  66  is  0.77044356609574
# auc roc score corresponding to  67  is  0.756816244284275
# auc roc score corresponding to  68  is  0.7547379162468677
# auc roc score corresponding to  69  is  0.7532550569634967
# auc roc score corresponding to  70  is  0.7714433335916713
# auc roc score corresponding to  71  is  0.7714213748740604
# auc roc score corresponding to  72  is  0.7869694386318427
# auc roc score corresponding to  73  is  0.7535133948177426
# auc roc score corresponding to  74  is  0.7708594900410758
# auc roc score corresponding to  75  is  0.7879808313312149
# auc roc score corresponding to  76  is  0.7457503422976569
# auc roc score corresponding to  77  is  0.7525807951639154
# auc roc score corresponding to  78  is  0.7502660879898732
# auc roc score corresponding to  79  is  0.7706683200289339
# auc roc score corresponding to  80  is  0.7753196930946291
# auc roc score corresponding to  81  is  0.7724547262910434
# auc roc score corresponding to  82  is  0.7615347851920742
# auc roc score corresponding to  83  is  0.7627593066211991
# auc roc score corresponding to  84  is  0.7663992869875222
# auc roc score corresponding to  85  is  0.7464129788937973
# auc roc score corresponding to  86  is  0.785340618460823
# auc roc score corresponding to  87  is  0.7569622051719237
# auc roc score corresponding to  88  is  0.7719716345036037
# auc roc score corresponding to  89  is  0.7595688341212637
# auc roc score corresponding to  90  is  0.7648712185796587
# auc roc score corresponding to  91  is  0.7573781291172595
# auc roc score corresponding to  92  is  0.7762070836239635
# auc roc score corresponding to  93  is  0.7586026505463845
# auc roc score corresponding to  94  is  0.7733085328993258
# auc roc score corresponding to  95  is  0.7524012503552145
# auc roc score corresponding to  96  is  0.7503229223178072
# auc roc score corresponding to  97  is  0.7697021364540548
# auc roc score corresponding to  98  is  0.7466377328269912
# auc roc score corresponding to  99  is  0.7508848071507918
# max auc roc score corresponding to  75  is  0.7879808313312149
# 75

# %%
#lets print the scores for logistic regression
print("LOGISTIC CLASSIFIER\n\n")
model_evaluation(lg_clf,x,y)
# Out:
# LOGISTIC CLASSIFIER
#
#
# Mean roc auc score for classifier:  0.8453161616717166
# standard deviation in roc auc score for classifier:  0.010953745129019256
# [0.85825519 0.85884161 0.83325454 0.83768891 0.83854056]

# %%
#Lets chcek the decision tree
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier()
max_aucroc_score(dc,df_x,y)
# Out:
# auc roc score corresponding to  42  is  0.6670877573690872
# auc roc score corresponding to  43  is  0.6681211087860705
# auc roc score corresponding to  44  is  0.678636751143145
# auc roc score corresponding to  45  is  0.6621896716525872
# auc roc score corresponding to  46  is  0.6852088661551577
# auc roc score corresponding to  47  is  0.656313777157767
# auc roc score corresponding to  48  is  0.6420574026712135
# auc roc score corresponding to  49  is  0.6714691673770958
# auc roc score corresponding to  50  is  0.6653685189490816
# auc roc score corresponding to  51  is  0.6668630034358933
# auc roc score corresponding to  52  is  0.6432031310547934
# auc roc score corresponding to  53  is  0.6486295176832261
# auc roc score corresponding to  54  is  0.65375235733292
# auc roc score corresponding to  55  is  0.6471014492753623
# auc roc score corresponding to  56  is  0.6652677671859258
# auc roc score corresponding to  57  is  0.6581337673409285
# auc roc score corresponding to  58  is  0.6641892066444495
# auc roc score corresponding to  59  is  0.6597625875119482
# auc roc score corresponding to  60  is  0.6716151282647446
# auc roc score corresponding to  61  is  0.6977240435040948
# auc roc score corresponding to  62  is  0.6521235371619003
# auc roc score corresponding to  63  is  0.6422821566044074
# auc roc score corresponding to  64  is  0.660066134490687
# auc roc score corresponding to  65  is  0.6570216228784004
# auc roc score corresponding to  66  is  0.6618409155493554
# auc roc score corresponding to  67  is  0.6506962205171923
# auc roc score corresponding to  68  is  0.6490674003461727
# auc roc score corresponding to  69  is  0.6606951871657755
# auc roc score corresponding to  70  is  0.6891071843757265
# auc roc score corresponding to  71  is  0.6601785114572839
# auc roc score corresponding to  72  is  0.6785579580976
# auc roc score corresponding to  73  is  0.6471802423209072
# auc roc score corresponding to  74  is  0.645023121237955
# auc roc score corresponding to  75  is  0.6746932237980832
# auc roc score corresponding to  76  is  0.6517411971376166
# auc roc score corresponding to  77  is  0.6547185409077992
# auc roc score corresponding to  78  is  0.6590999509158078
# auc roc score corresponding to  79  is  0.6551564235707459
# auc roc score corresponding to  80  is  0.6418998165801234
# auc roc score corresponding to  81  is  0.6536399803663231
# auc roc score corresponding to  82  is  0.6704358159601126
# auc roc score corresponding to  83  is  0.6567632850241546
# auc roc score corresponding to  84  is  0.6794905577514273
# auc roc score corresponding to  85  is  0.6323167738768761
# auc roc score corresponding to  86  is  0.6852540752796507
# auc roc score corresponding to  87  is  0.657583507711385
# auc roc score corresponding to  88  is  0.6515616523289157
# auc roc score corresponding to  89  is  0.6509325996538272
# auc roc score corresponding to  90  is  0.671177245601798
# auc roc score corresponding to  91  is  0.6417202717714227
# auc roc score corresponding to  92  is  0.6749631868557701
# auc roc score corresponding to  93  is  0.6442816915962696
# auc roc score corresponding to  94  is  0.6578754294866828
# auc roc score corresponding to  95  is  0.648741894649823
# auc roc score corresponding to  96  is  0.6871748172259681
# auc roc score corresponding to  97  is  0.6453150430132528
# auc roc score corresponding to  98  is  0.6572011676871012
# auc roc score corresponding to  99  is  0.666200366839753
# max auc roc score corresponding to  61  is  0.6977240435040948
# 61

# %%
#Lets print the scores of decision tree
print("Decision tree CLASSIFIER\n\n")
model_evaluation(dc,df_x,y)
# Out:
# Decision tree CLASSIFIER
#
#
# Mean roc auc score for classifier:  0.6498096425194276
# standard deviation in roc auc score for classifier:  0.012523764894229456
# [0.66078948 0.65346819 0.628784   0.64331292 0.66269362]

# %%
#lets chcek random forest also
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
parameters={"n_estimators":[10,100,500]}
rf_clf=RandomForestClassifier()
clf = GridSearchCV(rf_clf, parameters, cv=10,scoring="roc_auc")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rf_clf=RandomForestClassifier(n_estimators=500)
max_aucroc_score(rf_clf,df_x,y)
# Out:
# auc roc score corresponding to  42  is  0.7068472448267845
# auc roc score corresponding to  43  is  0.7137229068175359
# auc roc score corresponding to  44  is  0.6980508408897156
# auc roc score corresponding to  45  is  0.6873892376449922
# auc roc score corresponding to  46  is  0.7051396316102199
# auc roc score corresponding to  47  is  0.678693585471079
# auc roc score corresponding to  48  is  0.6866813919243586
# auc roc score corresponding to  49  is  0.6950734971195329
# auc roc score corresponding to  50  is  0.6958485106822703
# auc roc score corresponding to  51  is  0.6980844248107676
# auc roc score corresponding to  52  is  0.7036567723268491
# auc roc score corresponding to  53  is  0.6991294014311916
# auc roc score corresponding to  54  is  0.7053643855434136
# auc roc score corresponding to  55  is  0.7206993205714433
# auc roc score corresponding to  56  is  0.6891304347826088
# auc roc score corresponding to  57  is  0.6994549071275414
# auc roc score corresponding to  58  is  0.7099253403601229
# auc roc score corresponding to  59  is  0.6932870908574233
# auc roc score corresponding to  60  is  0.7085212741222972
# auc roc score corresponding to  61  is  0.7205533596837944
# auc roc score corresponding to  62  is  0.6997584541062801
# auc roc score corresponding to  63  is  0.6957477589191143
# auc roc score corresponding to  64  is  0.6997584541062801
# auc roc score corresponding to  65  is  0.7019827430313363
# auc roc score corresponding to  66  is  0.7056898912397633
# auc roc score corresponding to  67  is  0.7144979203802733
# auc roc score corresponding to  68  is  0.6985675165982071
# auc roc score corresponding to  69  is  0.7079258053682606
# auc roc score corresponding to  70  is  0.704802500710429
# auc roc score corresponding to  71  is  0.7038479423389911
# auc roc score corresponding to  72  is  0.7136776976930429
# auc roc score corresponding to  73  is  0.7123860084218141
# auc roc score corresponding to  74  is  0.6893551887158026
# auc roc score corresponding to  75  is  0.7259009532666822
# auc roc score corresponding to  76  is  0.6954106280193236
# auc roc score corresponding to  77  is  0.7226652716422537
# auc roc score corresponding to  78  is  0.7237774161047819
# auc roc score corresponding to  79  is  0.7051396316102199
# auc roc score corresponding to  80  is  0.7152057661009068
# auc roc score corresponding to  81  is  0.706364153039345
# auc roc score corresponding to  82  is  0.7137564907385878
# auc roc score corresponding to  83  is  0.6930739621276706
# auc roc score corresponding to  84  is  0.7036567723268491
# auc roc score corresponding to  85  is  0.7044653698106385
# auc roc score corresponding to  86  is  0.7072631687721201
# auc roc score corresponding to  87  is  0.7377870779405307
# auc roc score corresponding to  88  is  0.7115657857345836
# auc roc score corresponding to  89  is  0.7137900746596398
# auc roc score corresponding to  90  is  0.7041398641142887
# auc roc score corresponding to  91  is  0.7028365496396186
# auc roc score corresponding to  92  is  0.7166550414632256
# auc roc score corresponding to  93  is  0.6885801751530651
# auc roc score corresponding to  94  is  0.7115657857345836
# auc roc score corresponding to  95  is  0.6944108605233924
# auc roc score corresponding to  96  is  0.6946691983776382
# auc roc score corresponding to  97  is  0.7033196414270583
# auc roc score corresponding to  98  is  0.6949611201529361
# auc roc score corresponding to  99  is  0.6990170244645948
# max auc roc score corresponding to  87  is  0.7377870779405307
# 87

# %%
#lets chcek KNN
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings("ignore")
kc=KNeighborsClassifier()
neighbors={"n_neighbors":range(1,30)}
clf = GridSearchCV(kc, neighbors, cv=5,scoring="roc_auc")
clf.fit(x,y)
clf.best_params_
# Out:
# {'n_neighbors': 29}

# %%
kc=KNeighborsClassifier(n_neighbors=29)
max_aucroc_score(kc,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7312343382675863
# auc roc score corresponding to  43  is  0.7557144333359167
# auc roc score corresponding to  44  is  0.7546358727944407
# auc roc score corresponding to  45  is  0.7268077191350849
# auc roc score corresponding to  46  is  0.7347619416673126
# auc roc score corresponding to  47  is  0.7275155648557183
# auc roc score corresponding to  48  is  0.7376152832674572
# auc roc score corresponding to  49  is  0.7421542793665556
# auc roc score corresponding to  50  is  0.7272572270014726
# auc roc score corresponding to  51  is  0.7469851972409517
# auc roc score corresponding to  52  is  0.7475018729494434
# auc roc score corresponding to  53  is  0.7376604923919501
# auc roc score corresponding to  54  is  0.7197525123356325
# auc roc score corresponding to  55  is  0.7437830995375752
# auc roc score corresponding to  56  is  0.737952414167248
# auc roc score corresponding to  57  is  0.7285941253971945
# auc roc score corresponding to  58  is  0.7474682890283914
# auc roc score corresponding to  59  is  0.7214601255521973
# auc roc score corresponding to  60  is  0.7336045880802914
# auc roc score corresponding to  61  is  0.7289312562969852
# auc roc score corresponding to  62  is  0.7261450825389443
# auc roc score corresponding to  63  is  0.7345823968586117
# auc roc score corresponding to  64  is  0.756759409956341
# auc roc score corresponding to  65  is  0.7436371386499264
# auc roc score corresponding to  66  is  0.7150003875067814
# auc roc score corresponding to  67  is  0.7124725516029866
# auc roc score corresponding to  68  is  0.7372445684466145
# auc roc score corresponding to  69  is  0.7219096334185849
# auc roc score corresponding to  70  is  0.7443449843705598
# auc roc score corresponding to  71  is  0.7466144824201091
# auc roc score corresponding to  72  is  0.7395476504172156
# auc roc score corresponding to  73  is  0.7403007052623422
# auc roc score corresponding to  74  is  0.7333462502260456
# auc roc score corresponding to  75  is  0.7409297579374305
# auc roc score corresponding to  76  is  0.7040132785657082
# auc roc score corresponding to  77  is  0.7401095352502001
# auc roc score corresponding to  78  is  0.7327843653930611
# auc roc score corresponding to  79  is  0.7369526466713168
# auc roc score corresponding to  80  is  0.7358069182877367
# auc roc score corresponding to  81  is  0.7423790332997494
# auc roc score corresponding to  82  is  0.7368402697047198
# auc roc score corresponding to  83  is  0.7262238755844895
# auc roc score corresponding to  84  is  0.7497713709989924
# auc roc score corresponding to  85  is  0.7202020202020203
# auc roc score corresponding to  86  is  0.7335374202381875
# auc roc score corresponding to  87  is  0.7448952440001034
# auc roc score corresponding to  88  is  0.7464233124079671
# auc roc score corresponding to  89  is  0.7484344726032705
# auc roc score corresponding to  90  is  0.735390994342401
# auc roc score corresponding to  91  is  0.7286729184427394
# auc roc score corresponding to  92  is  0.7440866465163141
# auc roc score corresponding to  93  is  0.7237967914438503
# auc roc score corresponding to  94  is  0.7378064532795992
# auc roc score corresponding to  95  is  0.7290100493425301
# auc roc score corresponding to  96  is  0.7180448991190678
# auc roc score corresponding to  97  is  0.7277739027099641
# auc roc score corresponding to  98  is  0.7252124828851172
# auc roc score corresponding to  99  is  0.7494794492236947
# max auc roc score corresponding to  64  is  0.756759409956341
# 64

# %%
#Lets chcek SVM Classifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
svc=SVC()
parameters={"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1,1,10]}
clf = GridSearchCV(svc, parameters, cv=5,scoring="roc_auc")
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 0.001, 'kernel': 'linear'}

# %%
svc=SVC(C=0.001,kernel="linear")
max_aucroc_score(svc,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7477834612105712
# auc roc score corresponding to  43  is  0.7751621070035392
# auc roc score corresponding to  44  is  0.7761954584205224
# auc roc score corresponding to  45  is  0.7535017696143017
# auc roc score corresponding to  46  is  0.751648195510088
# auc roc score corresponding to  47  is  0.7472215763775867
# auc roc score corresponding to  48  is  0.7589617401637861
# auc roc score corresponding to  49  is  0.7504236740809631
# auc roc score corresponding to  50  is  0.7400539926115373
# auc roc score corresponding to  51  is  0.7658374021545378
# auc roc score corresponding to  52  is  0.7656914412668888
# auc roc score corresponding to  53  is  0.7701516443204424
# auc roc score corresponding to  54  is  0.7527603399726163
# auc roc score corresponding to  55  is  0.7737128316412204
# auc roc score corresponding to  56  is  0.7410201761864165
# auc roc score corresponding to  57  is  0.7545467462347258
# auc roc score corresponding to  58  is  0.7680616910795939
# auc roc score corresponding to  59  is  0.7376721175953912
# auc roc score corresponding to  60  is  0.7647588416130615
# auc roc score corresponding to  61  is  0.7578495957012582
# auc roc score corresponding to  62  is  0.7543219923015319
# auc roc score corresponding to  63  is  0.7596812110878607
# auc roc score corresponding to  64  is  0.7716345036038131
# auc roc score corresponding to  65  is  0.7589953240848382
# auc roc score corresponding to  66  is  0.7639722028468832
# auc roc score corresponding to  67  is  0.736897104032654
# auc roc score corresponding to  68  is  0.752872716939213
# auc roc score corresponding to  69  is  0.7519853264098788
# auc roc score corresponding to  70  is  0.7683200289338395
# auc roc score corresponding to  71  is  0.7671407166292077
# auc roc score corresponding to  72  is  0.7768245110956109
# auc roc score corresponding to  73  is  0.7476039164018703
# auc roc score corresponding to  74  is  0.760377431605053
# auc roc score corresponding to  75  is  0.783071120411274
# auc roc score corresponding to  76  is  0.7420315688857888
# auc roc score corresponding to  77  is  0.7536141465808985
# auc roc score corresponding to  78  is  0.7463677697693043
# auc roc score corresponding to  79  is  0.7675450153711024
# auc roc score corresponding to  80  is  0.7589281562427342
# auc roc score corresponding to  81  is  0.7527939238936681
# auc roc score corresponding to  82  is  0.7522772481851766
# auc roc score corresponding to  83  is  0.749345113539487
# auc roc score corresponding to  84  is  0.7653543103670982
# auc roc score corresponding to  85  is  0.7401327856570823
# auc roc score corresponding to  86  is  0.7582538944431527
# auc roc score corresponding to  87  is  0.7603322224805602
# auc roc score corresponding to  88  is  0.7748249761037483
# auc roc score corresponding to  89  is  0.7557376837427987
# auc roc score corresponding to  90  is  0.7428401663695782
# auc roc score corresponding to  91  is  0.7428853754940712
# auc roc score corresponding to  92  is  0.7722635562789015
# auc roc score corresponding to  93  is  0.7508279728228577
# auc roc score corresponding to  94  is  0.7650171794673073
# auc roc score corresponding to  95  is  0.7565914903510812
# auc roc score corresponding to  96  is  0.7515022346224393
# auc roc score corresponding to  97  is  0.7576584256891162
# auc roc score corresponding to  98  is  0.7419863597612957
# auc roc score corresponding to  99  is  0.7458627192642537
# max auc roc score corresponding to  75  is  0.783071120411274
# 75

# %%
#Cross val score for SVM classifier
print("SVM CLASSIFIER\n\n")
model_evaluation(svc,x,y)
# Out:
# SVM CLASSIFIER
#
#
# Mean roc auc score for classifier:  0.8350227641832401
# standard deviation in roc auc score for classifier:  0.00936720994836345
# [0.84778217 0.8445762  0.82894805 0.82972435 0.82408305]

# %%
import lightgbm as lgb
lg = lgb.LGBMClassifier(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="roc_auc")
grid_search.fit(df_x,y)
grid_search.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 25,
#  'n_estimators': 200,
#  'num_leaves': 300}

# %%
#LGBM also give provision to define which all columns should be treated as categorical
#So we will use above provision and see what is the result
params={'learning_rate': 0.01,'max_depth': 25,'n_estimators': 200,'num_leaves': 300}
max_auc_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20,stratify=y)
    x_train, y_train = SMOTE().fit_sample(x_train, y_train)
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train)
    y_pred = lgb_model.predict(x_test)
    roc_scr=roc_auc_score(y_test,y_pred)
    print("roc score corresponding to ",r_state," is ",roc_scr)
    if roc_scr>max_auc_score:
        max_auc_score=roc_scr
        final_r_state=r_state
print("max roc score corresponding to ",final_r_state," is ",max_auc_score)
# Out:
# roc score corresponding to  42  is  0.8279444056937663
# roc score corresponding to  43  is  0.849142318323904
# roc score corresponding to  44  is  0.8348730269446382
# roc score corresponding to  45  is  0.82351261980418
# roc score corresponding to  46  is  0.8189477899196569
# roc score corresponding to  47  is  0.8196892195613423
# roc score corresponding to  48  is  0.8305200341005967
# roc score corresponding to  49  is  0.8127903071637087
# roc score corresponding to  50  is  0.8194360484641814
# roc score corresponding to  51  is  0.8236340385956754
# roc score corresponding to  52  is  0.832918701077269
# roc score corresponding to  53  is  0.8232000310005425
# roc score corresponding to  54  is  0.830866206825286
# roc score corresponding to  55  is  0.8474476220000515
# roc score corresponding to  56  is  0.8201387274277301
# roc score corresponding to  57  is  0.8141375390736004
# roc score corresponding to  58  is  0.8259513291482601
# roc score corresponding to  59  is  0.808655609806505
# roc score corresponding to  60  is  0.8350629052675089
# roc score corresponding to  61  is  0.831588261127903
# roc score corresponding to  62  is  0.8099537575240899
# roc score corresponding to  63  is  0.8183833217081299
# roc score corresponding to  64  is  0.8330930791288848
# roc score corresponding to  65  is  0.8304024903769149
# roc score corresponding to  66  is  0.8177439355188717
# roc score corresponding to  67  is  0.8251879407889637
# roc score corresponding to  68  is  0.8161654912294297
# roc score corresponding to  69  is  0.8253093595804594
# roc score corresponding to  70  is  0.8330065359477123
# roc score corresponding to  71  is  0.8370404815417603
# roc score corresponding to  72  is  0.837964039370689
# roc score corresponding to  73  is  0.8359761295822675
# roc score corresponding to  74  is  0.8068679118551242
# roc score corresponding to  75  is  0.8415652690588752
# roc score corresponding to  76  is  0.8048735436203467
# roc score corresponding to  77  is  0.826147665917487
# roc score corresponding to  78  is  0.8252615670774238
# roc score corresponding to  79  is  0.8311400449507867
# roc score corresponding to  80  is  0.8178059366038906
# roc score corresponding to  81  is  0.8272740189619985
# roc score corresponding to  82  is  0.8301932367149758
# roc score corresponding to  83  is  0.8177193934227182
# roc score corresponding to  84  is  0.8297928130408949
# roc score corresponding to  85  is  0.8076390503500479
# roc score corresponding to  86  is  0.8432780490325247
# roc score corresponding to  87  is  0.8416983130538117
# roc score corresponding to  88  is  0.8279250303546979
# roc score corresponding to  89  is  0.8338525924203672
# roc score corresponding to  90  is  0.820984783900385
# roc score corresponding to  91  is  0.822683355292051
# roc score corresponding to  92  is  0.8448552016326953
# roc score corresponding to  93  is  0.8215492521119119
# roc score corresponding to  94  is  0.8370081893099797
# roc score corresponding to  95  is  0.8076506755534888
# roc score corresponding to  96  is  0.8314939678111034
# roc score corresponding to  97  is  0.8137694076313002
# roc score corresponding to  98  is  0.8194231315714691
# roc score corresponding to  99  is  0.8342775581906017
# max roc score corresponding to  43  is  0.849142318323904

# %%
type(df_x)
# Out:
# pandas.core.frame.DataFrame

# %%
#The above model i.e light gradient boosting works better when categorical features are defined
#So we will use this to create our final model
#Also when compared to random forest its giving better and fast results
#Lets chcek the cross_val_scores
import numpy as np
from sklearn.model_selection import KFold
scores=[]
k_fold = KFold(n_splits=5)
for train_index,test_index in k_fold.split(df_x):
    x_train, x_test, y_train, y_test = df_x.iloc[train_index], df_x.iloc[test_index], y[train_index], y[test_index]
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train)
    y_pred = lgb_model.predict(x_test)
    roc_scr=roc_auc_score(y_test,y_pred)
    scores.append(roc_scr)
print("Mean roc score for lgbm regressor: ",np.array(scores).mean())
print("standard deviation in roc score for lgbm regressor: ",np.array(scores).std())
print(scores)
# Out:
# Mean roc score for lgbm regressor:  0.827617986964572
# standard deviation in roc score for lgbm regressor:  0.011346437058833614
# [0.8388496692786236, 0.8384352489615647, 0.8167312644694744, 0.8115553208209587, 0.8325184312922383]

# %%
def dataTr(x,I=[]):
    for i in range(x):
        I.append(i*i)
    print(I)
    
    
dataTr(2)    
dataTr(3,[3,2,1])
dataTr(3)
# Out:
# [0, 1]
# [3, 2, 1, 0, 1, 4]
# [0, 1, 0, 1, 4]
